# %%
import pandas as pd

# %%
df = pd.read_excel('Datasets/output1.xlsx')
df.head()
# Out:
#    pclass  survived     sex      age  sibsp  parch  ticket    cabin embarked  \
# 0       1         1  female  29.0000      0      0   24160       B5        S
# 1       1         1    male   0.9167      1      2  113781  C22 C26        S
# 2       1         0  female   2.0000      1      2  113781  C22 C26        S
# 3       1         0    male  30.0000      1      2  113781  C22 C26        S
# 4       1         0  female  25.0000      1      2  113781  C22 C26        S
#
#   boat   body
# 0    2    NaN
# 1   11    NaN
# 2  NaN    NaN
# 3  NaN  135.0
# 4  NaN    NaN

# %% [markdown]
# # Outliers

# %%
df[df['age'] > 100]['age'].any()
# Out:
# False

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.hist(figsize = (15, 10))
plt.show()

# %%
rows_need_to_drop = df[4 > df['age']]['age'].index
df.drop(rows_need_to_drop, inplace = True)

# %%
df.hist(figsize = (15, 10))
plt.show()

# %%
df.shape
# Out:
# (1268, 11)

# %%
df.to_excel("Datasets/output2.xlsx", index = False)

# %% [markdown]
# # Bye
